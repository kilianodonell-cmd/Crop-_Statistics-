# %% [markdown]
# <a href="https://colab.research.google.com/github/kilianodonell-cmd/Crop-_Statistics-/blob/main/notebooks/01_data%20(version%201).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 01 – Data loading
#
# Purpose:
# - load raw data
# - initial inspection
# - basic cleaning

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_fieldwork = pd.read_csv("../content/drive/MyDrive/Data_Mastery/data/gaza_fieldwork_crop_covers.csv")

df_fieldwork.head()
# Out:
#     id  formid    plotid  enumerator_id    gid        report_close_time  \
# 0  820      20   9624988              1  18418  2025-04-10 12:06:32.653
# 1  820      20   9624988              1  18418  2025-04-10 12:06:32.653
# 2  821      20  12364565              2   9045  2025-04-10 12:06:45.057
# 3  821      20  12364565              2   9058  2025-04-10 12:06:45.057
# 4  821      20  12364565              2   9065  2025-04-10 12:06:45.057
#
#    total_crop_cover                          crop_po  crop_cover_percentage
# 0                80                          feijões                     30
# 1                80                            milho                     50
# 2               100                            trigo                    100
# 3               100  batata doce de polpa alaranjada                    100
# 4               100                          feijões                    100

# %%
gdf_sa = gpd.read_file("../content/drive/MyDrive/Data_Mastery/data/shapefiles/moz_sampling_areas.shp")

gdf_sa.head()
# Out:
#        plotid  optional  prov          stratum  fcname  \
# 0  10084432.0         0  Gaza  scarce alluvial  scarce
# 1  12014580.0         1  Gaza  scarce alluvial  scarce
# 2  10264592.0         0  Gaza  scarce alluvial  scarce
# 3   7015055.0         0  Gaza  scarce alluvial  scarce
# 4   9884543.0         0  Gaza  scarce alluvial  scarce
#
#                                             geometry
# 0  POLYGON ((503500 7216000, 503500 7216500, 5040...
# 1  POLYGON ((600000 7290000, 600000 7290500, 6005...
# 2  POLYGON ((512500 7296000, 512500 7296500, 5130...
# 3  POLYGON ((350000 7527500, 350000 7528000, 3505...
# 4  POLYGON ((493500 7271500, 493500 7272000, 4940...

# %%
missing_plotids = sorted(
    set(df_1["plotid"].unique())
    - set(gdf_sa["plotid"].unique())
)

missing_plotids
# Out:
# []

# %%
missing_plotids = sorted(
  set(gdf_sa["plotid"].unique())
   - set(df_fieldwork["plotid"].unique())

)

missing_plotids
# Out:
# [np.float64(6975045.0),
#  np.float64(6994897.0),
#  np.float64(7015055.0),
#  np.float64(7035055.0),
#  np.float64(7155097.0),
#  np.float64(7275020.0),
#  np.float64(7494842.0),
#  np.float64(7744825.0),
#  np.float64(7784866.0),
#  np.float64(7874793.0),
#  np.float64(7894767.0),
#  np.float64(7954783.0),
#  np.float64(8144868.0),
#  np.float64(8164864.0),
#  np.float64(8205137.0),
#  np.float64(8234973.0),
#  np.float64(8334712.0),
#  np.float64(8354714.0),
#  np.float64(8504703.0),
#  np.float64(8514772.0),
#  np.float64(8734827.0),
#  np.float64(8744647.0),
#  np.float64(8954774.0),
#  np.float64(8985043.0),
#  np.float64(9024738.0),
#  np.float64(9134725.0),
#  np.float64(9185144.0),
#  np.float64(9495244.0),
#  np.float64(9534651.0),
#  np.float64(9555059.0),
#  np.float64(9715241.0),
#  np.float64(9754786.0),
#  np.float64(9864553.0),
#  np.float64(9864618.0),
#  np.float64(9884543.0),
#  np.float64(9904539.0),
#  np.float64(10004537.0),
#  np.float64(10084432.0),
#  np.float64(10264438.0),
#  np.float64(10264592.0),
#  np.float64(10274416.0),
#  np.float64(10294412.0),
#  np.float64(10294468.0),
#  np.float64(10294501.0),
#  np.float64(10314432.0),
#  np.float64(10314574.0),
#  np.float64(10325175.0),
#  np.float64(10354511.0),
#  np.float64(10374458.0),
#  np.float64(10384424.0),
#  np.float64(10404535.0),
#  np.float64(10424539.0),
#  np.float64(10474489.0),
#  np.float64(10484564.0),
#  np.float64(10564416.0),
#  np.float64(10584515.0),
#  np.float64(10624422.0),
#  np.float64(10644778.0),
#  np.float64(10684677.0),
#  np.float64(10684681.0),
#  np.float64(10694677.0),
#  np.float64(10714495.0),
#  np.float64(10734525.0),
#  np.float64(10764446.0),
#  np.float64(10784495.0),
#  np.float64(10784529.0),
#  np.float64(10824574.0),
#  np.float64(10884738.0),
#  np.float64(10894422.0),
#  np.float64(10894432.0),
#  np.float64(10944452.0),
#  np.float64(11004454.0),
#  np.float64(11024497.0),
#  np.float64(11034460.0),
#  np.float64(11054454.0),
#  np.float64(11074550.0),
#  np.float64(11104444.0),
#  np.float64(11104448.0),
#  np.float64(11144794.0),
#  np.float64(11164890.0),
#  np.float64(11194463.0),
#  np.float64(11204489.0),
#  np.float64(11204695.0),
#  np.float64(11214479.0),
#  np.float64(11274562.0),
#  np.float64(11384487.0),
#  np.float64(11434469.0),
#  np.float64(11434481.0),
#  np.float64(11444651.0),
#  np.float64(11514703.0),
#  np.float64(11614572.0),
#  np.float64(11644722.0),
#  np.float64(11754687.0),
#  np.float64(11774475.0),
#  np.float64(11774738.0),
#  np.float64(11784584.0),
#  np.float64(11794734.0),
#  np.float64(11814467.0),
#  np.float64(11864683.0),
#  np.float64(12034499.0),
#  np.float64(12194485.0),
#  np.float64(12194524.0),
#  np.float64(12734545.0)]

# %%
print(gdf_sa.columns)
# Out:
# Index(['plotid', 'optional', 'prov', 'stratum', 'fcname', 'geometry'], dtype='object')

# %%
print(gdf_sa["fcname"].unique())
# Out:
# ['scarce' 'regular' 'irrigated']

# %%
print(gdf_sa["optional"].unique())
# Out:
# [0 1 2]

# %%
gdf_seg = gpd.read_file("../content/drive/MyDrive/Data_Mastery/data/shapefiles/moz_segments.shp")

gdf_seg
# Out:
#          gid     id    plotid   landform_e          landform_p farming_ty  \
# 0      24063  23663  10714495    pediplain           pediplano    regular
# 1      24017  23625  10714495    pediplain           pediplano    regular
# 2      24016  23624  10714495    pediplain           pediplano    regular
# 3      24011  23621  10714495    pediplain           pediplano    regular
# 4      24009  23619  10714495    pediplain           pediplano    regular
# ...      ...    ...       ...          ...                 ...        ...
# 39565  18096  17744  11754687  flood plain  plano de inundação    regular
# 39566  18083  17730  11754687  flood plain  plano de inundação    regular
# 39567  18082  17729  11754687  flood plain  plano de inundação    regular
# 39568  18031  17731  11754687  flood plain  plano de inundação    regular
# 39569  18088  17736  11754687  flood plain  plano de inundação    regular
#
#       farming__1        profile  optional    cuo_class_          cuo_clas_1  \
# 0        regular  10 early pedi         1  uncultivated  terra no cultivada
# 1        regular  10 early pedi         1    cultivated     terra cultivada
# 2        regular  10 early pedi         1    cultivated     terra cultivada
# 3        regular  10 early pedi         1  uncultivated  terra no cultivada
# 4        regular  10 early pedi         1  uncultivated  terra no cultivada
# ...          ...            ...       ...           ...                 ...
# 39565    regular    24-33 flood         0  uncultivated  terra no cultivada
# 39566    regular    24-33 flood         0  uncultivated  terra no cultivada
# 39567    regular    24-33 flood         0  uncultivated  terra no cultivada
# 39568    regular    24-33 flood         0  uncultivated  terra no cultivada
# 39569    regular    24-33 flood         0  uncultivated  terra no cultivada
#
#                segment_cl       segment__1  code  tasked district  \
# 0           open woodland  floresta aberta   205     NaN   Bilene
# 1      agricultural field   campo agrícola   301     NaN   Bilene
# 2      agricultural field   campo agrícola   301     NaN   Bilene
# 3                   other            outro   208     NaN   Bilene
# 4                   other            outro   208     NaN   Bilene
# ...                   ...              ...   ...     ...      ...
# 39565       open woodland  floresta aberta   205     3.0  Chibuto
# 39566              forest         floresta   206     NaN  Chibuto
# 39567       open woodland  floresta aberta   205     NaN  Chibuto
# 39568              forest         floresta   206     NaN  Chibuto
# 39569              forest         floresta   206     1.0  Chibuto
#
#          areasize_w                                           geometry
# 0          0.000000  POLYGON ((534750 7248011.259, 534750 7248250.0...
# 1          0.000000  POLYGON ((535235.705 7247274.049, 535236.34 72...
# 2          0.000000  POLYGON ((535452.472 7248230.195, 535463.051 7...
# 3          0.000000  POLYGON ((535692.434 7247897.073, 535710.954 7...
# 4          0.000000  POLYGON ((535596.353 7248121.187, 535590.474 7...
# ...             ...                                                ...
# 39565  47685.362811  POLYGON ((586750.001 7343633.066, 586750.001 7...
# 39566      0.000000  POLYGON ((587342.877 7343250.004, 587370.583 7...
# 39567      0.000000  POLYGON ((587655.757 7344250, 587749.999 73442...
# 39568      0.000000  POLYGON ((587500.084 7343404.832, 587504.355 7...
# 39569  96504.760372  POLYGON ((587103.311 7344155.229, 587120.635 7...
#
# [39570 rows x 18 columns]

# %%
missing_plotids = sorted(
    set(df_1["plotid"].unique())
    - set(gdf_seg["plotid"].unique())
)

missing_plotids
# Out:
# []

# %%
missing_plotids = sorted(
    set(gdf_seg["plotid"].unique())
    - set(df_1["plotid"].unique())
)

len(missing_plotids)
# Out:
# 103

# %%
print(gdf_seg.columns)
# Out:
# Index(['gid', 'id', 'plotid', 'landform_e', 'landform_p', 'farming_ty',
#        'farming__1', 'profile', 'optional', 'cuo_class_', 'cuo_clas_1',
#        'segment_cl', 'segment__1', 'code', 'tasked', 'district', 'areasize_w',
#        'geometry'],
#       dtype='object')

# %%
gdf_seg["district"].unique()
# Out:
# array(['Bilene', 'Xai-Xai', 'Mandlakaze', 'Chibuto', 'Chokwe',
#        'Chicualacuala_Black', 'Guija', 'Massingir', 'Mabalane', 'Chigubo',
#        'Chicualacuala', 'Massangena', 'Cidade de Xai-Xai'], dtype=object)

# %%
for col in gdf_seg.columns:
    print(col)
    print(gdf_seg[col].unique())
    print("------")
# Out:
# gid
# [24063 24017 24016 ... 18082 18031 18088]
# ------
# id
# [23663 23625 23624 ... 17729 17731 17736]
# ------
# plotid
# [10714495 10474489 10944477 12034499 12194524 11614572 10294521 10294468
#  12734545 11004454 11104448  7644979 10824574 10784529 11164473  8234973
#  10734673  9534651  8514772  9024738 10244478  8734827 11184541  9504638
#  10084432 10694677 10884738 10484564 10784479 11034460 11034521  9884543
#   9864618 11514703  9754786 10624485  9594616 11784584 10354511  8744647
#   8205137 10274416  8164864 11074511 10734683  9185144 10314505 10154468
#   6994897 10734525 10204588 10894432  9715241  6975045 11054454 11184525
#  11384487  8634655 11774475 10264438  7744825 10764446  7275020  9134725
#  11434481 12014580  7035055 11114719  9624988 10325175  8354714 11024497
#  10244521  8504703 11944595 10564416 11104444 10974726 11774738 11794734
#  11444651  7894767 10374458 12034495 11074550  9495244 11094515  7015055
#  10684677 10314574  9555059 10584515 10294501 10624511 11324527 10624422
#   7784866  8104969  9864553 10204586 11204695 11144794 10644778  7494842
#  10784495 10134470 11274562 10024549 11714687  8985043 10404535 11164890
#   7954783  8954774 10314432 10894422  8144868 10244557 11204489 11194463
#  11714691 11864683 12194485  8334712  9244675 10004537  9904539 10684681
#  11264657  7874793  9064730 11814467  7155097  9954478 10294412  9774596
#  11214479 11434469 11134630 10424539 12204477 11434538 12364565 10384424
#  10944452 10264592 11734696 11644722 11754687]
# ------
# landform_e
# ['pediplain' 'alluvial plain' 'flood plain']
# ------
# landform_p
# ['pediplano' 'plano alluvial' 'plano de inundação']
# ------
# farming_ty
# ['regular' 'irrigated' 'scarce']
# ------
# farming__1
# ['regular' 'irrigada' 'escassa']
# ------
# profile
# ['10 early pedi' '12 late pedi' '5 late pedi' '6 early coastal pedi'
#  '7 early pedi' '8 late pedi' 'irrigated alluvial' '5 early alluvial'
#  '7 late alluvial' '9 early alluvial' '9 flood' '12 flood' '24-33 flood'
#  'scarce western pedi' '4 early inland pedi' 'scarce alluvial' '32 flood'
#  '6 early alluvial' '23 flood' 'scarce flood' '11 late pedi'
#  '6 early inland pedi' 'scarce coastal pedi' '8 early alluvial' '17 flood']
# ------
# optional
# [1 0 2]
# ------
# cuo_class_
# ['uncultivated' 'cultivated' 'objects']
# ------
# cuo_clas_1
# ['terra no cultivada' 'terra cultivada' 'objeto']
# ------
# segment_cl
# ['open woodland' 'agricultural field' 'other' 'path' 'forest' 'tree'
#  'building' 'grassland' 'marsh' 'surface water' 'shore' 'barren'
#  'kitchen garden' 'orchard']
# ------
# segment__1
# ['floresta aberta' 'campo agrícola' 'outro' 'caminho' 'floresta' 'árvore'
#  'construção' 'pastagem' 'pradaria' 'pântano' 'águas de superfície'
#  'ribeirinha' 'barras' 'horta' 'pomar']
# ------
# code
# [205 301 208 101 206 105 103 302 204 304 203 201 202 207 305 303]
# ------
# tasked
# [nan  3.  2.  1.]
# ------
# district
# ['Bilene' 'Xai-Xai' 'Mandlakaze' 'Chibuto' 'Chokwe' 'Chicualacuala_Black'
#  'Guija' 'Massingir' 'Mabalane' 'Chigubo' 'Chicualacuala' 'Massangena'
#  'Cidade de Xai-Xai']
# ------
# areasize_w
# [    0.           442.80912296  1320.46064246 ...   658.94469392
#  47685.36281102 96504.76037232]
# ------
# geometry
# <GeometryArray>
# [<POLYGON ((534750 7248011.259, 534750 7248250.001, 534785.597 7248250.001, 5...>,
#  <POLYGON ((535235.705 7247274.049, 535236.34 7247276.589, 535246.713 7247279...>,
#  <POLYGON ((535452.472 7248230.195, 535463.051 7248237.463, 535481.571 724823...>,
#  <POLYGON ((535692.434 7247897.073, 535710.954 7247897.602, 535713.065 724786...>,
#  <POLYGON ((535596.353 7248121.187, 535590.474 7248136.724, 535596.98 7248140...>,
#  <POLYGON ((535681.945 7248078.606, 535692.797 7248081.255, 535693.473 724810...>,
#  <POLYGON ((535575.26 7248034.675, 535586.335 7248101.121, 535648.55 7248087....>,
#  <POLYGON ((535674.895 7247522.549, 535674.689 7247517.59, 535678.779 7247517...>,
#  <POLYGON ((535701.851 7247937.174, 535705.24 7247948.612, 535719.002 7247947...>,
#  <POLYGON ((535446.089 7248115.478, 535459.579 7248113.359, 535460.379 724810...>,
#  ...
#  <POLYGON ((587654.389 7343662.06, 587639.307 7343652.932, 587632.562 7343657...>,
#  <POLYGON ((587002.926 7344121.866, 587045.59 7344119.557, 587055.839 7344123...>,
#  <POLYGON ((586979.771 7344142.442, 586983.746 7344144.422, 586986.121 734417...>,
#  <POLYGON ((586912.782 7344250, 587056.326 7344250, 587064.481 7344226.535, 5...>,
#  <POLYGON ((586934.271 7344145.791, 586943.259 7344145.611, 586953.583 734414...>,
#  <POLYGON ((586750.001 7343633.066, 586750.001 7344201.98, 586764.25 7344197....>,
#  <POLYGON ((587342.877 7343250.004, 587370.583 7343270.08, 587395.766 7343304...>,
#  <POLYGON ((587655.757 7344250, 587749.999 7344250, 587749.999 7343901.351, 5...>,
#  <POLYGON ((587500.084 7343404.832, 587504.355 7343412.741, 587501.816 734341...>,
#  <POLYGON ((587103.311 7344155.229, 587120.635 7344146.691, 587126.193 734413...>]
# Length: 39570, dtype: geometry
# ------

# %%
gdf_stra = gpd.read_file("../content/drive/MyDrive/Data_Mastery/data/shapefiles/moz_strata.shp")

gdf_stra.head()
# Out:
#    id  province_i province cluster       stratum   fcname   landform  \
# 0  41           2     Gaza    q03a   5 late pedi  regular  pediplain
# 1  42           2     Gaza    q03b   8 late pedi  regular  pediplain
# 2  44           2     Gaza    q03c  11 late pedi  regular  pediplain
# 3  45           2     Gaza     q19  12 late pedi  regular  pediplain
# 4  54           2     Gaza    q16a  7 early pedi  regular  pediplain
#
#                                             geometry
# 0  MULTIPOLYGON (((521420.02 7201748.95, 521372.0...
# 1  MULTIPOLYGON (((521429.52 7202601.43, 521564.2...
# 2  MULTIPOLYGON (((525552.176 7211794.603, 525634...
# 3  MULTIPOLYGON (((524569.02 7212062.67, 524569.0...
# 4  MULTIPOLYGON (((507665.229 7247408.124, 506763...

# %%
gdf_stra["id"].nunique()
# Out:
# 37

# %%
gdf_stra[gdf_stra["province"] == "Gaza"]["stratum"].nunique()
# Out:
# 27

# %%
print(gdf_seg.geom_type.unique())
# Out:
# ['Polygon']

# %%
# sample 6 random polygons
sampled = gdf_seg.sample(6)

fig, axes = plt.subplots(2, 3, figsize=(12, 8))

for ax, (_, row) in zip(axes.flatten(), sampled.iterrows()):
    gdf_seg.iloc[[row.name]].plot(
        ax=ax,
        facecolor="none",
        edgecolor="red"
    )
    ax.set_axis_off()

plt.tight_layout()
plt.show()

# %%
gdf_seg[gdf_seg["plotid"].isin(gdf_sa["plotid"])].groupby("plotid").size()
# Out:
# plotid
# 6975045       2
# 6994897       3
# 7015055     132
# 7035055      16
# 7155097     241
#            ...
# 12194485    942
# 12194524     96
# 12204477    154
# 12364565    212
# 12734545      9
# Length: 149, dtype: int64

# %%
#lot_id = gdf_sa["plotid"].iloc[1]
plot_id= 9624988
sam_plot = gdf_sa[gdf_sa["plotid"] == plot_id]
seg_plot = gdf_seg[gdf_seg["plotid"] == plot_id]


fig, ax = plt.subplots(figsize=(8, 8))

# plot main plot polygon
sam_plot.plot(
    ax=ax,
    facecolor="none",
    edgecolor="black",
    linewidth=2,
    label="Plot"
)

# plot segments inside
seg_plot.plot(
    ax=ax,
    facecolor="none",
    edgecolor="red",
    linewidth=1,
    label="Segments"
)

# add segment label
for _, row in seg_plot[seg_plot["gid"] == 18427].iterrows():
    x, y = row.geometry.representative_point().coords[0]
    ax.text(
        x, y,
        str(row["gid"]),
        fontsize=8,
        color="blue",
        ha="center",
        va="center"
    )

highlight_gid = [18427, 18423, 18421, 18418, 18417, 18412, 18413, 18396, 18419, 1998, 1926, 1916, 18150]

# Plot highlighted segment boundaries in green
seg_plot[seg_plot["gid"].isin(highlight_gid)].plot(
    ax=ax,
    facecolor="none",
    edgecolor="green",
    linewidth=3,
    label="Highlighted segments"
)

# Add gid labels for highlighted segments
for _, row in seg_plot[seg_plot["gid"].isin(highlight_gid)].iterrows():
    x, y = row.geometry.representative_point().coords[0]
    ax.text(
        x, y,
        str(row["gid"]),
        fontsize=8,
        color="green",
        ha="center",
        va="center",
        fontweight="bold"
    )



ax.set_title(f"Plot {plot_id} and its segments")
ax.set_axis_off()

plt.show()

gid_list = seg_plot["gid"].tolist()
print(gid_list)
# Out:
# [18427, 18423, 18421, 18418, 18417, 18410, 18409, 18412, 18413, 18406, 18407, 18396, 18419, 1900, 2008, 1957, 1956, 1923, 1922, 1731, 2003, 2002, 2001, 2000, 1999, 1998, 2006, 2005, 2004, 1996, 1995, 1994, 1993, 1992, 1991, 1990, 1989, 1988, 1986, 1985, 1984, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971, 1970, 1969, 1967, 1966, 1965, 1963, 1962, 1961, 1960, 1959, 1958, 1951, 1950, 1949, 1948, 1947, 1946, 1945, 1944, 1942, 1941, 1940, 1987, 1954, 1953, 1939, 1938, 1937, 1936, 1952, 1932, 1931, 1930, 1929, 1928, 1964, 1935, 1934, 1933, 1926, 1943, 1925, 1924, 1916, 1894, 1955, 1917, 1890, 1906, 1868, 1851, 2007, 18150]

# %%
gdf_seg.head()
# Out:
#      gid     id    plotid landform_e landform_p farming_ty farming__1  \
# 0  24063  23663  10714495  pediplain  pediplano    regular    regular
# 1  24017  23625  10714495  pediplain  pediplano    regular    regular
# 2  24016  23624  10714495  pediplain  pediplano    regular    regular
# 3  24011  23621  10714495  pediplain  pediplano    regular    regular
# 4  24009  23619  10714495  pediplain  pediplano    regular    regular
#
#          profile  optional    cuo_class_          cuo_clas_1  \
# 0  10 early pedi         1  uncultivated  terra no cultivada
# 1  10 early pedi         1    cultivated     terra cultivada
# 2  10 early pedi         1    cultivated     terra cultivada
# 3  10 early pedi         1  uncultivated  terra no cultivada
# 4  10 early pedi         1  uncultivated  terra no cultivada
#
#            segment_cl       segment__1  code  tasked district  areasize_w  \
# 0       open woodland  floresta aberta   205     NaN   Bilene         0.0
# 1  agricultural field   campo agrícola   301     NaN   Bilene         0.0
# 2  agricultural field   campo agrícola   301     NaN   Bilene         0.0
# 3               other            outro   208     NaN   Bilene         0.0
# 4               other            outro   208     NaN   Bilene         0.0
#
#                                             geometry
# 0  POLYGON ((534750 7248011.259, 534750 7248250.0...
# 1  POLYGON ((535235.705 7247274.049, 535236.34 72...
# 2  POLYGON ((535452.472 7248230.195, 535463.051 7...
# 3  POLYGON ((535692.434 7247897.073, 535710.954 7...
# 4  POLYGON ((535596.353 7248121.187, 535590.474 7...

# %%
relations = pd.DataFrame({
    "rows": [
        len(gdf_seg),
        gdf_seg["plotid"].nunique(),
        gdf_seg["id"].nunique(),
        gdf_seg["gid"].nunique()
    ]
}, index=[
    "total rows",
    "unique plotid",
    "unique id",
    "unique gid"
])

print(relations)
# Out:
#                 rows
# total rows     39570
# unique plotid    149
# unique id      39570
# unique gid     39570

# %%
relations_df1 = pd.DataFrame({
    "rows": [
        len(df_1),
        df_1["plotid"].nunique(),
        df_1["id"].nunique(),
        df_1["gid"].nunique()
    ]
}, index=[
    "total rows",
    "unique plotid",
    "unique id",
    "unique gid"
])

print(relations_df1)
# Out:
#                rows
# total rows     1837
# unique plotid    46
# unique id       127
# unique gid     1071

# %%
gdf_seg["profile"].nunique()
# Out:
# 25

# %%
all_profiles = set(gdf_seg["profile"].unique())
gdf_profiles = set(gdf_seg["profile"].unique())

#sorted(all_profiles - visited_profiles)

# %%
missing_gids = gdf_seg.loc[
    ~gdf_seg["gid"].isin(df_1["gid"]),
    "gid"
].unique()

missing_gids
# Out:
# array([24063, 24017, 24016, ..., 18082, 18031, 18088])

# %%
gdf_seg.loc[
    gdf_seg["gid"].isin(missing_gids),
    ["gid", "plotid", "profile"]
].sort_values(["profile", "plotid"])
# Out:
#          gid    plotid              profile
# 31961  14592  10134470        10 early pedi
# 31962  14584  10134470        10 early pedi
# 31963  20498  10134470        10 early pedi
# 31964  20491  10134470        10 early pedi
# 31965  20490  10134470        10 early pedi
# ...      ...       ...                  ...
# 4796   30868   8514772  scarce western pedi
# 4797   30877   8514772  scarce western pedi
# 4798   30876   8514772  scarce western pedi
# 4799   30871   8514772  scarce western pedi
# 4800   30870   8514772  scarce western pedi
#
# [38499 rows x 3 columns]

# %%
# for checking whether gdf_seg contains all segments or only visited & cultivated ones
segments_per_sa = (
    gdf_seg
    .groupby("plotid", as_index=False)["gid"]
    .nunique()
    .rename(columns={"gid": "n_segments"})
)

#print(segments_per_sa)

segments_check = (
    gdf_seg
    .groupby("plotid", as_index=False)["gid"]
    .nunique()
    .rename(columns={"gid":"segments_all"})
)

#print(segments_check)

# %%
gdf_seg["district"].unique()
# Out:
# array(['Bilene', 'Xai-Xai', 'Mandlakaze', 'Chibuto', 'Chokwe',
#        'Chicualacuala_Black', 'Guija', 'Massingir', 'Mabalane', 'Chigubo',
#        'Chicualacuala', 'Massangena', 'Cidade de Xai-Xai'], dtype=object)

# %%
gdf_seg["district"].nunique()
# Out:
# 13

# %%
gdf_districts = gpd.read_file("../content/drive/MyDrive/Data_Mastery/data/shapefiles/moz_districts.shp")
print(gdf_districts)
# Out:
#      id           distrito provincia  \
# 0   245             Bilene      Gaza
# 1   234            Chibuto      Gaza
# 2   239      Chicualacuala      Gaza
# 3   237            Chigubo      Gaza
# 4   235             Chokwe      Gaza
# 5   257  Cidade de Xai-Xai      Gaza
# 6   233              Guija      Gaza
# 7   240           Mabalane      Gaza
# 8   255         Mandlakaze      Gaza
# 9   246         Massangena      Gaza
# 10  231          Massingir      Gaza
# 11  254            Xai-Xai      Gaza
#
#                                              geometry
# 0   POLYGON ((532097.573 7214125.683, 532050.89 72...
# 1   POLYGON ((584811.374 7276535.453, 584220.059 7...
# 2   POLYGON ((426324.548 7424471.797, 426364.262 7...
# 3   POLYGON ((575761.32 7446613.826, 575911.731 74...
# 4   POLYGON ((520960.775 7274858.993, 521180.785 7...
# 5   POLYGON ((562930.7 7236477.437, 562936.87 7236...
# 6   POLYGON ((505491.567 7287528.412, 505278.671 7...
# 7   POLYGON ((501586.373 7386919.497, 501694.151 7...
# 8   POLYGON ((611754.891 7235585.217, 611678.626 7...
# 9   POLYGON ((447457.63 7640836.655, 447494.213 76...
# 10  POLYGON ((456309.783 7313369.692, 455366.365 7...
# 11  POLYGON ((560309.388 7227104.739, 560389.394 7...

# %% [markdown]
# ## Formula 1

# %%
#cp=visited segment for a particular crop

crop_area_seg = df_1.merge(
    gdf_seg[["gid", "areasize_w", "optional"]],
    on="gid",
    how="left"
)

crop_area_seg["crop_cover_sqm"] = np.where(
    crop_area_seg["optional"].isin([0, 2]),
    crop_area_seg["areasize_w"] * (crop_area_seg["total_crop_cover"] / 100) * (crop_area_seg["crop_cover_percentage"] / 100),
    0
)
print(crop_area_seg.head())
# Out:
#     id  formid    plotid  enumerator_id    gid        report_close_time  \
# 0  820      20   9624988              1  18418  2025-04-10 12:06:32.653
# 1  820      20   9624988              1  18418  2025-04-10 12:06:32.653
# 2  821      20  12364565              2   9045  2025-04-10 12:06:45.057
# 3  821      20  12364565              2   9058  2025-04-10 12:06:45.057
# 4  821      20  12364565              2   9065  2025-04-10 12:06:45.057
#
#    total_crop_cover                          crop_po  crop_cover_percentage  \
# 0                80                          feijões                     30
# 1                80                            milho                     50
# 2               100                            trigo                    100
# 3               100  batata doce de polpa alaranjada                    100
# 4               100                          feijões                    100
#
#      areasize_w  optional  crop_cover_sqm
# 0  11374.813650         0     2729.955276
# 1  11374.813650         0     4549.925460
# 2   6485.110940         0     6485.110940
# 3   1115.380969         0     1115.380969
# 4   1076.102814         0     1076.102814

# %%
crop_area_seg["crop_cover_sqm"].describe()
# Out:
# count     1837.000000
# mean      1251.963897
# std       3036.985986
# min          0.000000
# 25%         83.529160
# 50%        398.191309
# 75%       1131.205972
# max      62272.796734
# Name: crop_cover_sqm, dtype: float64

# %% [markdown]
# ## Formula 2

# %%
#sa_cp = observed crop area of a particular crop for each SA using only the visited segments
crop_area_sa = (
    crop_area_seg.groupby(["plotid", "crop_po"])["crop_cover_sqm"]
      .sum()
      .reset_index(name="vis_crop_area")
)
print(crop_area_sa.head())
# Out:
#     plotid   crop_po  vis_crop_area
# 0  7644979   abóbora    2546.707067
# 1  7644979   feijões     608.909714
# 2  7644979    mapira    1620.692235
# 3  7644979  mexoeira    4470.740775
# 4  7644979     milho   54061.913867

# %%
# checking specific plot and crop
crop_area_sa_plot = crop_area_sa[
    (crop_area_sa["plotid"] == 9624988) &
    (crop_area_sa["crop_po"] == "feijões")
]

print(crop_area_sa_plot)
# Out:
#      plotid  crop_po  vis_crop_area
# 39  9624988  feijões    2729.955276

# %% [markdown]
# ## Formula 3

# %%
# cultivated areas using all segments (gdf_seg)

gdf_cult = gdf_seg[gdf_seg["cuo_class_"] == "cultivated"]

cult_sa = (gdf_cult
    .groupby("plotid", as_index=False)["areasize_w"]
    .sum()
    .rename(columns={"areasize_w": "cult_sa_sqm"})
)

print(cult_sa.head(8))
# Out:
#     plotid    cult_sa_sqm
# 0  7015055   70613.434551
# 1  7155097  116802.647230
# 2  7644979  118460.836291
# 3  8104969     478.839229
# 4  8205137  156468.642569
# 5  8334712   16255.823615
# 6  8354714  167480.239045
# 7  8504703       0.000000

# %% [markdown]
# ## Formula 4

# %%
# formula 4 different approach using gid from fieldwork file

# Step 1: unique visited segment gids per plotid from df_1
visited_gids = df_1[["plotid", "gid"]].drop_duplicates()

# Step 2: attach segment areas from gdf_seg
visited_gids = visited_gids.merge(
    gdf_seg[["gid", "areasize_w"]],
    on="gid",
    how="left"
)

# Step 3: sum visited segment area per sampling area
sa_visited_seg = (
    visited_gids
    .groupby("plotid", as_index=False)["areasize_w"]
    .sum()
    .rename(columns={"areasize_w": "sa_visited_sqm"})
)

# %%
## THE GOOD ONE
full_crop_area = (
    crop_area_sa.merge(cult_sa, on="plotid", how="left")
         .merge(sa_visited_seg, on="plotid", how="left")
)

full_crop_area["full_crop_sqm"]= (
    full_crop_area["vis_crop_area"]
    * full_crop_area["cult_sa_sqm"]
    / full_crop_area["sa_visited_sqm"]
)
full_crop_area
# Out:
#        plotid                          crop_po  vis_crop_area    cult_sa_sqm  \
# 0     7644979                          abóbora    2546.707067  118460.836291
# 1     7644979                          feijões     608.909714  118460.836291
# 2     7644979                           mapira    1620.692235  118460.836291
# 3     7644979                         mexoeira    4470.740775  118460.836291
# 4     7644979                            milho   54061.913867  118460.836291
# ..        ...                              ...            ...            ...
# 196  12364565  batata doce de polpa alaranjada    1115.380969   73617.084895
# 197  12364565                          feijões    1862.903969   73617.084895
# 198  12364565                         mexoeira    3730.725984   73617.084895
# 199  12364565                            milho    3632.925278   73617.084895
# 200  12364565                            trigo   15984.466839   73617.084895
#
#      sa_visited_sqm  full_crop_sqm
# 0     115791.589698    2605.414173
# 1     115791.589698     622.946400
# 2     115791.589698    1658.052696
# 3     115791.589698    4573.801020
# 4     115791.589698   55308.157914
# ..              ...            ...
# 196    61640.756505    1332.090976
# 197    61640.756505    2224.851988
# 198    61640.756505    4455.577560
# 199    61640.756505    4338.774924
# 200    61640.756505   19090.126712
#
# [201 rows x 6 columns]

# %% [markdown]
# ### Formula 5

# %%
##helper for F5
# ---------- add profile once (needed for F5/F6) ----------this is just adding "profile"
plotid_to_profile = (
    gdf_seg.groupby("plotid", as_index=False)["profile"].first()
)
full_crop_area = full_crop_area.merge(plotid_to_profile, on="plotid", how="left")

# %%
## here again A_sj1 becuase
stratum_crop_area = (
    full_crop_area
    .rename(columns={"profile": "stratum"})
    .groupby(["stratum", "crop_po"], as_index=False)["full_crop_sqm"]
    .sum()
    .rename(columns={"full_crop_sqm": "stratum_crop_sqm"})
)

stratum_crop_area
# Out:
#              stratum                              crop_po  stratum_crop_sqm
# 0      10 early pedi                              abóbora        242.399663
# 1      10 early pedi                     amendoim pequeno       1990.525589
# 2      10 early pedi      batata doce de polpa alaranjada         42.618289
# 3      10 early pedi  batata doce de polpa nāo alaranjada       3368.962608
# 4      10 early pedi                       cana de açucar        145.491569
# ..               ...                                  ...               ...
# 121  scarce alluvial      batata doce de polpa alaranjada          0.000000
# 122  scarce alluvial  batata doce de polpa nāo alaranjada          0.000000
# 123  scarce alluvial                              feijões          0.000000
# 124  scarce alluvial                             mandioca          0.000000
# 125  scarce alluvial                                milho          0.000000
#
# [126 rows x 3 columns]

# %% [markdown]
# ## Formula 6

# %% [markdown]
# so here i have two different approaches with complete different results

# %%
PLOT_AREA = 500 * 500  # all sampling areas in gaza are 500 x 500m

stratum_sa_area = (
    gdf_sa[
        (gdf_sa["prov"] == "Gaza") &
        (gdf_sa["optional"].isin([0, 2]))
    ]
    .groupby("stratum", as_index=False)["plotid"]
    .nunique()
    .assign(stratum_sa_sqm=lambda x: x["plotid"] * PLOT_AREA)
    .drop(columns="plotid")
)

print(stratum_sa_area.head())
# Out:
#          stratum  stratum_sa_sqm
# 0  10 early pedi         1000000
# 1   11 late pedi          750000
# 2       12 flood          750000
# 3   12 late pedi          750000
# 4       17 flood          750000

# %% [markdown]
# ## Formula 7

# %% [markdown]
# ## below is the outcome for the code that is running, oucome is depending on which f 6 is used

# %%
# Merge stratum crop area with total stratum area
stratum_crop_perc = (
    stratum_crop_area
    .merge(stratum_sa_area, on="stratum", how="left")
)

# Calculate stratum crop percentage
stratum_crop_perc["scp_value"] = stratum_crop_perc["stratum_crop_sqm"] / stratum_crop_perc["stratum_sa_sqm"] *100

print(stratum_crop_perc.head())
# Out:
#          stratum                              crop_po  stratum_crop_sqm  \
# 0  10 early pedi                              abóbora        242.399663
# 1  10 early pedi                     amendoim pequeno       1990.525589
# 2  10 early pedi      batata doce de polpa alaranjada         42.618289
# 3  10 early pedi  batata doce de polpa nāo alaranjada       3368.962608
# 4  10 early pedi                       cana de açucar        145.491569
#
#    stratum_sa_sqm  scp_value
# 0         1000000   0.024240
# 1         1000000   0.199053
# 2         1000000   0.004262
# 3         1000000   0.336896
# 4         1000000   0.014549

# %%
# adding english name to scp

# Read crop list with Portuguese and English names
crop_list = pd.read_csv(
    "../content/drive/MyDrive/Data_Mastery/data/crop_list.csv"
)

# Merge English crop names into scp
scp_table = (
    stratum_crop_perc
    .merge(crop_list[["crop_po", "crop_en"]], on="crop_po", how="left")
)

print(scp_table.head())
# Out:
#          stratum                              crop_po  stratum_crop_sqm  \
# 0  10 early pedi                              abóbora        242.399663
# 1  10 early pedi                     amendoim pequeno       1990.525589
# 2  10 early pedi      batata doce de polpa alaranjada         42.618289
# 3  10 early pedi  batata doce de polpa nāo alaranjada       3368.962608
# 4  10 early pedi                       cana de açucar        145.491569
#
#    stratum_sa_sqm  scp_value                          crop_en
# 0         1000000   0.024240                           squash
# 1         1000000   0.199053                     small peanut
# 2         1000000   0.004262      orange-fleshed sweet potato
# 3         1000000   0.336896  non-orange-fleshed sweet potato
# 4         1000000   0.014549                        sugarcane

# %%
scp_pivot = (
    scp_table
    .pivot_table(
        index="stratum",
        columns="crop_en",
        values="scp_value",
        aggfunc="sum",   # safe even if one value per cell
        fill_value=0
    )
)

print(scp_pivot)
# Out:
# crop_en                  beans   cassava       corn  large peanut   lettuce  \
# stratum
# 10 early pedi         3.603130  2.989630   1.518633      0.000000  0.000000
# 11 late pedi          5.522835  7.322433   7.252966      0.752721  0.000000
# 12 flood              2.830493  0.549631  18.120427      0.000000  0.000000
# 12 late pedi          3.203864  2.658242   1.412663      0.000000  0.000000
# 17 flood              1.208079  0.725309   7.561745      0.396997  0.000000
# 23 flood              1.137770  0.016187   3.850287      0.000000  0.000000
# 24-33 flood           1.036731  0.000000   3.725084      0.000000  0.000000
# 32 flood              0.046841  0.000000   5.280856      0.000000  0.000000
# 4 early inland pedi   0.062191  0.063166   0.000000      0.000000  0.000000
# 5 early alluvial      0.054845  0.000000   6.171954      0.000000  0.000000
# 5 late pedi           2.167621  3.337923   0.813808      0.000000  0.000000
# 6 early alluvial      0.638425  2.692733   6.782136      0.000000  0.000000
# 6 early coastal pedi  5.215901  3.550196  15.348170      0.104670  0.000000
# 6 early inland pedi   0.000000  0.000000   0.000000      0.000000  0.000000
# 7 early pedi          9.343504  7.662884   5.465384      0.203352  0.000000
# 7 late alluvial       1.134883  1.180319  50.903645      0.000000  0.000000
# 8 early alluvial      0.000000  0.000000   0.000000      0.000000  0.000000
# 8 late pedi           1.482880  0.865251   2.584357      0.000000  0.104316
# 9 early alluvial      0.000000  0.000000   0.000000      0.000000  0.000000
# 9 flood               0.017979  0.000000   0.000252      0.000000  0.000000
# irrigated alluvial    0.049836  0.000000   4.424653      0.000000  0.000000
# scarce alluvial       0.000000  0.000000   0.000000      0.000000  0.000000
#
# crop_en               macadamia nuts    millet  \
# stratum
# 10 early pedi               0.000000  0.000000
# 11 late pedi                0.000000  0.000000
# 12 flood                    0.000000  0.000000
# 12 late pedi                0.000000  0.000000
# 17 flood                    0.000000  0.000000
# 23 flood                    0.000000  0.000000
# 24-33 flood                 0.000000  0.000000
# 32 flood                    0.000000  0.000000
# 4 early inland pedi         0.000000  0.000000
# 5 early alluvial            0.000000  0.000000
# 5 late pedi                 0.000000  0.000000
# 6 early alluvial            0.000000  0.000000
# 6 early coastal pedi        0.000000  0.000000
# 6 early inland pedi         0.000000  0.000000
# 7 early pedi                0.000000  0.000000
# 7 late alluvial             0.260056  0.000000
# 8 early alluvial            0.000000  0.000000
# 8 late pedi                 0.000000  0.594077
# 9 early alluvial            0.000000  0.000000
# 9 flood                     0.000000  0.000900
# irrigated alluvial          0.000000  0.365904
# scarce alluvial             0.000000  0.000000
#
# crop_en               non-orange-fleshed sweet potato      okra  \
# stratum
# 10 early pedi                                0.336896  0.000000
# 11 late pedi                                 0.135563  0.000000
# 12 flood                                     0.000000  0.000000
# 12 late pedi                                 0.030250  0.000000
# 17 flood                                     0.000000  0.000000
# 23 flood                                     0.000000  0.000000
# 24-33 flood                                  0.000000  0.003814
# 32 flood                                     0.000000  0.000000
# 4 early inland pedi                          0.103651  0.000000
# 5 early alluvial                             0.000000  0.000000
# 5 late pedi                                  0.000000  0.000000
# 6 early alluvial                             0.293532  0.236113
# 6 early coastal pedi                         0.095245  0.000000
# 6 early inland pedi                          0.000000  0.000000
# 7 early pedi                                 0.109744  0.000000
# 7 late alluvial                              0.904844  0.282734
# 8 early alluvial                             0.000000  0.000000
# 8 late pedi                                  0.074553  0.000000
# 9 early alluvial                             0.000000  0.000000
# 9 flood                                      0.000452  0.000000
# irrigated alluvial                           0.000000  0.000000
# scarce alluvial                              0.000000  0.000000
#
# crop_en               orange-fleshed sweet potato  other vegetable  piri-piri  \
# stratum
# 10 early pedi                            0.004262         0.007606   0.000000
# 11 late pedi                             0.133177         1.626833   0.000000
# 12 flood                                 0.000000         0.000000   0.000000
# 12 late pedi                             0.000000         0.000000   0.000000
# 17 flood                                 0.000000         0.052183   0.000000
# 23 flood                                 0.000000         0.000000   0.000000
# 24-33 flood                              0.000000         0.000000   0.000000
# 32 flood                                 0.000000         0.000000   0.000000
# 4 early inland pedi                      0.000000         0.000000   0.000000
# 5 early alluvial                         0.006183         0.089336   0.000000
# 5 late pedi                              0.000000         0.036311   0.000000
# 6 early alluvial                         0.621930         0.145601   0.000000
# 6 early coastal pedi                     0.290466         0.001794   0.000000
# 6 early inland pedi                      0.000000         0.000000   0.000000
# 7 early pedi                             0.000000         0.000000   0.000000
# 7 late alluvial                          0.000000         0.000000   0.000000
# 8 early alluvial                         0.000000         0.000000   0.000000
# 8 late pedi                              0.177612         0.000000   0.000000
# 9 early alluvial                         0.000000         0.000000   0.000000
# 9 flood                                  0.000000         0.000450   0.000164
# irrigated alluvial                       0.000000         0.079370   0.000000
# scarce alluvial                          0.000000         0.000000   0.000000
#
# crop_en                    rice  small peanut   sorghum    squash  sugarcane  \
# stratum
# 10 early pedi          0.000000      0.199053  0.000000  0.024240   0.014549
# 11 late pedi           0.000000      0.033829  0.000000  0.000000   0.000000
# 12 flood               0.000000      0.000000  0.000000  0.081767   0.000000
# 12 late pedi           0.000000      0.000000  0.000000  0.000000   0.000000
# 17 flood               0.000000      0.771387  0.000000  0.019320   0.000000
# 23 flood               0.000000      0.121596  0.000000  0.205819   0.000000
# 24-33 flood            0.000000      0.000000  0.000000  0.048182   0.000000
# 32 flood               0.000000      1.042221  0.000000  0.000000   0.000000
# 4 early inland pedi    0.000000      0.000000  0.000000  0.003101   0.000000
# 5 early alluvial       0.000000      0.000000  0.000000  0.282168   0.000000
# 5 late pedi            0.000000      0.000000  0.000000  0.000000   0.000000
# 6 early alluvial       0.000000      0.000000  0.000000  0.948916   0.000000
# 6 early coastal pedi   0.000000      0.372367  0.000000  0.335945   0.000000
# 6 early inland pedi    0.000000      0.000000  0.000000  0.000000   0.000000
# 7 early pedi           0.000000      0.000000  0.000000  0.000000   0.000000
# 7 late alluvial        0.000000      0.000000  0.000000  5.699709   0.022202
# 8 early alluvial      48.246215      0.000000  0.000000  0.000000   0.000000
# 8 late pedi            5.023189      1.030305  0.000000  0.262067   0.049735
# 9 early alluvial      27.810561      0.000000  0.000000  0.000000   0.000000
# 9 flood                0.000000      0.000000  0.002630  0.013983   0.000000
# irrigated alluvial     0.000000      0.000000  0.132644  0.208433   0.000000
# scarce alluvial        0.000000      0.000000  0.000000  0.000000   0.000000
#
# crop_en                 wheat
# stratum
# 10 early pedi         0.00000
# 11 late pedi          0.00000
# 12 flood              0.00000
# 12 late pedi          0.00000
# 17 flood              0.00000
# 23 flood              0.00000
# 24-33 flood           0.00000
# 32 flood              0.00000
# 4 early inland pedi   0.00000
# 5 early alluvial      0.00000
# 5 late pedi           0.00000
# 6 early alluvial      0.00000
# 6 early coastal pedi  0.00000
# 6 early inland pedi   0.00000
# 7 early pedi          0.00000
# 7 late alluvial       0.00000
# 8 early alluvial      0.00000
# 8 late pedi           2.54535
# 9 early alluvial      0.00000
# 9 flood               0.00000
# irrigated alluvial    0.00000
# scarce alluvial       0.00000

# %%
scp_pivot.to_csv("scp_stratum_crop_table.csv")

from google.colab import files

files.download("scp_stratum_crop_table.csv")
